# %%
df = io.load('preprocessed_shuttles')
df.head()
# Out:
# 2019-06-20 21:39:57,397 - kedro.io.data_catalog - INFO - Loading data from `preprocessed_shuttles` (CSVLocalDataSet)...
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0              True
# 2      1.0                   2            moderate   0.0             False
# 3      3.0                   6              strict   3.0             False
# 4      2.0                   4              strict   2.0             False
#
#    moon_clearance_complete   price  company_id
# 0                    False  1325.0       35029
# 1                    False  1780.0       30292
# 2                    False  1715.0       19032
# 3                    False  4770.0        8238
# 4                    False  2820.0       30342

# %%
import pandas as pd

def create_master_table(
    shuttles: pd.DataFrame, companies: pd.DataFrame, reviews: pd.DataFrame
) -> pd.DataFrame:
    """Combines all data to create a master table.

        Args:
            shuttles: Preprocessed data for shuttles.
            companies: Preprocessed data for companies.
            reviews: Source data for reviews.
        Returns:
            Master table.

    """
    rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")

    with_companies = rated_shuttles.merge(
        companies, left_on="company_id", right_on="id"
    )

    master_table = with_companies.drop(["shuttle_id", "company_id"], axis=1)
    master_table = master_table.dropna()
    return master_table

# %%
preprocessed_shuttles = io.load("preprocessed_shuttles")
preprocessed_companies = io.load("preprocessed_companies")
reviews = io.load("reviews")

master = create_master_table(preprocessed_shuttles, preprocessed_companies, reviews)
master.head()
# Out:
# 2019-06-20 21:42:15,217 - kedro.io.data_catalog - INFO - Loading data from `preprocessed_shuttles` (CSVLocalDataSet)...
# 2019-06-20 21:42:15,423 - kedro.io.data_catalog - INFO - Loading data from `preprocessed_companies` (CSVLocalDataSet)...
# 2019-06-20 21:42:15,490 - kedro.io.data_catalog - INFO - Loading data from `reviews` (CSVLocalDataSet)...
#     id_x shuttle_location shuttle_type engine_type             engine_vendor  \
# 0  63561             Niue      Type V5     Quantum        ThetaBase Services
# 1  63561             Niue      Type V5     Quantum        ThetaBase Services
# 2  63561             Niue      Type V5     Quantum        ThetaBase Services
# 3  63561             Niue      Type V5     Quantum        ThetaBase Services
# 4  53260             Niue      Type V5     Quantum  Banks, Wood and Phillips
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0             False
# 2      1.0                   2              strict   1.0             False
# 3      1.0                   2              strict   1.0             False
# 4      1.0                   2              strict   1.0             False
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                10.0                     9.0                 10.0
# 1  ...                10.0                     9.0                 10.0
# 2  ...                10.0                     9.0                 10.0
# 3  ...                10.0                     9.0                 10.0
# 4  ...                10.0                     9.0                 10.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                133               1.65  35029             1.0
# 1                133               1.65  35029             1.0
# 2                133               1.65  35029             1.0
# 3                133               1.65  35029             1.0
# 4                 37               0.48  35029             1.0
#
#    company_location  total_fleet_count  iata_approved
# 0              Niue                4.0          False
# 1              Niue                4.0          False
# 2              Niue                4.0          False
# 3              Niue                4.0          False
# 4              Niue                4.0          False
#
# [5 rows x 26 columns]

# %%
preprocessed_shuttles.head()
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0              True
# 2      1.0                   2            moderate   0.0             False
# 3      3.0                   6              strict   3.0             False
# 4      2.0                   4              strict   2.0             False
#
#    moon_clearance_complete   price  company_id
# 0                    False  1325.0       35029
# 1                    False  1780.0       30292
# 2                    False  1715.0       19032
# 3                    False  4770.0        8238
# 4                    False  2820.0       30342

# %%
preprocessed_companies.head()
# Out:
#       id  company_rating       company_location  total_fleet_count  \
# 0  35029            1.00                   Niue                4.0
# 1  30292            0.67               Anguilla                6.0
# 2  19032            0.67     Russian Federation                4.0
# 3   8238            0.91               Barbados               15.0
# 4  30342             NaN  Sao Tome and Principe                2.0
#
#    iata_approved
# 0          False
# 1          False
# 2          False
# 3           True
# 4           True

# %%
reviews.head()
# Out:
#    shuttle_id  review_scores_rating  review_scores_comfort  \
# 0       63561                  97.0                   10.0
# 1       36260                  90.0                    8.0
# 2       57015                  95.0                    9.0
# 3       14035                  93.0                   10.0
# 4       10036                  98.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                10.0                10.0
# 1                      9.0                10.0                 9.0
# 2                     10.0                 9.0                10.0
# 3                      9.0                 9.0                 9.0
# 4                     10.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                 10.0                133
# 1                     9.0                  9.0                  3
# 2                     9.0                  9.0                 14
# 3                    10.0                  9.0                 39
# 4                     9.0                  9.0                 92
#
#    reviews_per_month
# 0               1.65
# 1               0.09
# 2               0.14
# 3               0.42
# 4               0.94
